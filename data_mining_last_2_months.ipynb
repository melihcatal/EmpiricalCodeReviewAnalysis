# %% [markdown]
# ## Mine the same GitHub Java repositories as the paper and get last 2 months data

# %% [markdown]
# <p> The code put in comments is used to run the script with colab. </p>

# %%
# %pip install PyGithub
# !pip install PyGithub
# Out:
# Requirement already satisfied: PyGithub in c:\users\eleon\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.58.2)
# Requirement already satisfied: requests>=2.14.0 in c:\users\eleon\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from PyGithub) (2.27.1)
# Requirement already satisfied: pyjwt[crypto]>=2.4.0 in c:\users\eleon\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from PyGithub) (2.7.0)
# Requirement already satisfied: deprecated in c:\users\eleon\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from PyGithub) (1.2.13)
# Requirement already satisfied: pynacl>=1.4.0 in c:\users\eleon\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from PyGithub) (1.5.0)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\eleon\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pyjwt[crypto]>=2.4.0->PyGithub) (40.0.2)
# Requirement already satisfied: cffi>=1.4.1 in c:\users\eleon\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pynacl>=1.4.0->PyGithub) (1.15.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\eleon\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.14.0->PyGithub) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\eleon\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.14.0->PyGithub) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\eleon\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.14.0->PyGithub) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\eleon\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.14.0->PyGithub) (3.3)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\eleon\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from deprecated->PyGithub) (1.14.1)
# Requirement already satisfied: pycparser in c:\users\eleon\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\eleon\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import requests
from github import Github
from datetime import datetime, timedelta
import os
import pandas as pd
from github import GithubException
import time

# %%
# If you want to run the code un colab, mount the drive and then unzip the data folder
"""
from google.colab import drive
drive.mount('/content/drive')

# !unzip '/content/drive/My Drive/github_old.zip'
"""

# %% [markdown]
# ### Directories

# %%
# Directory with dataset of the original paper
dir_path = './github_old/'

# Directory to sabe the new dataset
new_gh_data_dir = "./data/"

# %% [markdown]
# ### Functions

# %%
"""Returns true if the csv file is empty"""
def is_csv_empty(path):
    try:
        if os.stat(dir_path + path).st_size == 0:
            return True
            
    except FileNotFoundError:
        return False

# %%
def get_commit(repo,id):
    try :
        return repo.get_commit(id)
    except:
        return None

# %%
def extract_data(raw_data, key):
    try :
        if key in raw_data:
            return raw_data[key]
        else:
            return None
    except:
        return None

# %%
def get_file_content(file_url):
    try:
        response = requests.get(file_url)
        if response.status_code == 200:  
            content = response.content.decode('utf-8')
            return content
        else:
            return None
    except:
        return None

# %%
def find_file(files, file_path):
    try:
        target_file_name = file_path.split("/")[-1]
        for file in files:
            current_file_name = file["filename"].split("/")[-1]
            if current_file_name == target_file_name:
                return file["raw_url"]
    except Exception as e:
        print(e)
        return None

# %%
def handle_rate_limit_exception(e):
    # Extract the retry-after value from the exception
    retry_after = int(e.headers.get("x-ratelimit-reset")) + 5
    current_timestamp = time.time()
    time_difference = retry_after - current_timestamp
    print(time_difference)
    time.sleep(time_difference)
    # Retry the failed operation

# %% [markdown]
# ### Delete empty folders in the dataset of the original paper

# %%
entries = os.listdir(dir_path)

for entry in entries:
    if is_csv_empty(entry):
        os.remove(dir_path + entry)

print(len(entries))
# Out:
# 1764

# %% [markdown]
# ### Get all the names of the projects

# %%
gh_projects = []
for filename in os.listdir(dir_path):
    df = pd.read_csv(dir_path + filename)
    gh_project = df['project'].iloc[0]
    gh_projects.append(gh_project)
# Out:
# C:\Users\eleon\AppData\Local\Temp\ipykernel_17600\1778706459.py:3: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(dir_path + filename)

# %%
gh_projects
# Out:
# ['52North/sensorweb-server-helgoland',
#  '52North/SensorWebClient',
#  '52North/sos-importer',
#  '52North/WPS',
#  'A24Group/ssGWT-lib',
#  'aaberg/sql2o',
#  'aboutsip/pkts',
#  'abstractj/kalium',
#  'ACRA/acra',
#  'Activiti/Activiti',
#  'AddstarMC/Minigames',
#  'AddstarMC/Prism-Bukkit',
#  'addthis/stream-lib',
#  'adennie/vroom',
#  'adjust/android_sdk',
#  'Adobe-Consulting-Services/acs-aem-commons',
#  'adobe-research/mesh',
#  'aerogear-attic/aerogear-simplepush-server',
#  'aerogear/aerogear-android-cookbook',
#  'aerogear/aerogear-unifiedpush-java-client',
#  'aerogear/aerogear-unifiedpush-server',
#  'aeshell/aesh-extensions',
#  'aeshell/aesh',
#  'Agilefreaks/DroidOmni',
#  'aikuma/aikuma',
#  'airlift/aircompressor',
#  'airlift/airlift',
#  'airlift/slice',
#  'ajanata/PretendYoureXyzzy',
#  'akvo/akvo-flow-mobile',
#  'akvo/akvo-flow',
#  'alecgorge/jsonapi',
#  'alengel/ASE5',
#  'alengel/ASE5_Java_Server',
#  'alexo/wro4j',
#  'Alfresco/alfresco-android-app',
#  'Alfresco/alfresco-android-sdk',
#  'Alfresco/gytheio',
#  'algolia/algoliasearch-client-android',
#  'algolia/algoliasearch-client-java',
#  'alibaba/canal',
#  'alibaba/druid',
#  'alibaba/fastjson',
#  'alibaba/jstorm',
#  'alkacon/opencms-core',
#  'allure-framework/allure1',
#  'Alluxio/alluxio',
#  'amlcurran/ShowcaseView',
#  'AMPATH/openmrs-module-amrsreports',
#  'amplitude/Amplitude-Android',
#  'anathema/anathema_legacy',
#  'AndlyticsProject/andlytics',
#  'android-async-http/android-async-http',
#  'android-spa-titech/HQTP',
#  'androidannotations/androidannotations',
#  'angelozerr/tern.java',
#  'AnimeNeko/Atarashii',
#  'anjlab/android-inapp-billing-v3',
#  'ankidroid/Anki-Android',
#  'AntennaPod/AntennaPod',
#  'AntiqueAtlasTeam/AntiqueAtlas',
#  'antlr/antlr3',
#  'antlr/antlr4',
#  'antlr/intellij-plugin-v4',
#  'antlr/stringtemplate4',
#  'AnySoftKeyboard/AnySoftKeyboard',
#  'aodn/talend-components',
#  'apache/accumulo',
#  'apache/activemq',
#  'apache/ambari',
#  'apache/aries',
#  'apache/attic-aurora',
#  'apache/avro',
#  'apache/bigtop',
#  'apache/bookkeeper',
#  'apache/camel',
#  'apache/cassandra',
#  'apache/cayenne',
#  'apache/cloudstack',
#  'apache/commons-collections',
#  'apache/commons-compress',
#  'apache/commons-csv',
#  'apache/commons-imaging',
#  'apache/commons-io',
#  'apache/commons-lang',
#  'apache/commons-vfs',
#  'apache/cordova-android',
#  'apache/cordova-plugin-inappbrowser',
#  'apache/deltaspike',
#  'apache/drill',
#  'apache/druid',
#  'apache/dubbo',
#  'apache/falcon',
#  'apache/flume',
#  'apache/fluo',
#  'apache/giraph',
#  'apache/hive',
#  'apache/httpcomponents-client',
#  'apache/httpcomponents-core',
#  'apache/isis',
#  'apache/jackrabbit-oak',
#  'apache/jackrabbit',
#  'apache/jena',
#  'apache/jmeter',
#  'apache/kafka',
#  'apache/karaf',
#  'apache/logging-log4j2',
#  'apache/maven-enforcer',
#  'apache/maven-plugins',
#  'apache/maven-scm',
#  'apache/maven-surefire',
#  'apache/maven-wagon',
#  'apache/maven',
#  'apache/metamodel',
#  'apache/mina-sshd',
#  'apache/nutch',
#  'apache/oodt',
#  'apache/openjpa',
#  'apache/opennlp',
#  'apache/poi',
#  'apache/shiro',
#  'apache/sqoop',
#  'apache/storm',
#  'apache/tez',
#  'apache/tika',
#  'apache/tomcat',
#  'apache/tomee',
#  'apache/usergrid',
#  'apache/wicket',
#  'apache/zookeeper',
#  'apereo/cas',
#  'apereo/java-cas-client',
#  'apereo/person-directory',
#  'apigee/apigee-android-sdk',
#  'apiman/apiman',
#  'apollo-rsps/apollo',
#  'appcelerator-modules/ti.map',
#  'AppLovin/SDK-Network-Adapters',
#  'apps4av/avare',
#  'apptentive/apptentive-android',
#  'ArcBees/Arcbees-Archetypes',
#  'ArcBees/arcbees-website',
#  'ArcBees/gwtchosen',
#  'ArcBees/gwtp-eclipse-plugin',
#  'ArcBees/gwtp-idea-plugin',
#  'ArcBees/GWTP-Samples',
#  'ArcBees/GWTP',
#  'ArcBees/gwtquery-tooltip-plugin',
#  'ArcBees/gwtquery',
#  'ArcBees/IDE-Templates',
#  'ArcBees/jciwebsite',
#  'archimatetool/archi',
#  'arduino/Arduino',
#  'argparse4j/argparse4j',
#  'arquillian/arquillian-container-glassfish',
#  'arquillian/arquillian-container-tomcat',
#  'arquillian/arquillian-container-weld',
#  'arquillian/arquillian-container-wls',
#  'arquillian/arquillian-core',
#  'arquillian/arquillian-droidium',
#  'arquillian/arquillian-extension-drone',
#  'arquillian/arquillian-extension-jacoco',
#  'arquillian/arquillian-extension-persistence',
#  'arquillian/arquillian-extension-spring',
#  'arquillian/arquillian-extension-warp',
#  'arquillian/arquillian-graphene',
#  'ArtificerRepo/artificer',
#  'ARUP-NGS/Pipeline',
#  'arx-deidentifier/arx',
#  'asakusafw/asakusafw',
#  'asciidoctor/asciidoctor-intellij-plugin',
#  'asciidoctor/asciidoctorj',
#  'asterics/AsTeRICS',
#  'asterisk-java/asterisk-java',
#  'AsyncHttpClient/async-http-client',
#  'atilika/kuromoji',
#  'atlasapi/atlas-applications',
#  'atlasapi/atlas-deer',
#  'atlasapi/atlas-feeds',
#  'atlasapi/atlas-model',
#  'atlasapi/atlas-persistence',
#  'atlasapi/atlas',
#  'ATLauncher/ATLauncher',
#  'Atmosphere/atmosphere',
#  'AuthMe/AuthMeReloaded',
#  'Automattic/simplenote-android',
#  'awaitility/awaitility',
#  'Awful/Awful.apk',
#  'awslabs/amazon-kinesis-client',
#  'awslabs/aws-sdk-android-samples',
#  'aws/aws-sdk-java',
#  'axemblr/axemblr-provisionr',
#  'AxonFramework/AxonFramework',
#  'azkaban/azkaban-plugins',
#  'azkaban/azkaban',
#  'AzureAD/azure-activedirectory-library-for-android',
#  'Azure/azure-sdk-for-java',
#  'babymastodon/hairy-octo-robot',
#  'balanced/balanced-java',
#  'BanManagement/BanManager',
#  'barbeau/gpstest',
#  'bartdag/py4j',
#  'BaseballCardTracker/bbct',
#  'BaseXdb/basex',
#  'basho/riak-java-client',
#  'bastillion-io/Bastillion',
#  'BatooOrg/BatooJPA',
#  'battlecode/battlecode-server-2017',
#  'BayesianLogic/blog',
#  'bazaarvoice/jolt',
#  'bazaarvoice/ostrich',
#  'bcgit/bc-java',
#  'bedatadriven/activityinfo',
#  'belaban/JGroups',
#  'bennidi/mbassador',
#  'bguerout/jongo',
#  'bigbluebutton/bigbluebutton',
#  'bigdataviewer/bigdataviewer-core',
#  'bilibili/DanmakuFlameMaster',
#  'bio4j/bio4j',
#  'bioclipse/bioclipse.cheminformatics',
#  'biojava/biojava',
#  'bitbar/testdroid-api',
#  'bitcoin-wallet/bitcoin-wallet',
#  'bitcoinj/bitcoinj',
#  'bitstadium/HockeySDK-Android',
#  'bluesoft-rnd/aperte-workflow-core',
#  'BlueText/bigsky',
#  'bndtools/bnd',
#  'bndtools/bndtools',
#  'bonitasoft/bonita-engine',
#  'bonitasoft/bonita-studio',
#  'bonitasoft/bonita-web',
#  'branflake2267/GWT-Maps-V3-Api',
#  'brave/link-bubble',
#  'brettwooldridge/HikariCP',
#  'briandilley/jsonrpc4j',
#  'brianfrankcooper/YCSB',
#  'BrightcoveOS/android-player-samples',
#  'brix-cms/brix-cms',
#  'BroadleafCommerce/BroadleafCommerce',
#  'brooklyncentral/brooklyn',
#  'buchen/portfolio',
#  'buddycloud/buddycloud-server-java',
#  'bugsnag/bugsnag-android',
#  'bugsnag/bugsnag-java',
#  'BuildCraft/BuildCraft',
#  'bujiio/buji-pac4j',
#  'Bukkit/Bukkit-JavaDoc',
#  'Bukkit/Bukkit',
#  'bumptech/glide',
#  'caelum/caelum-stella',
#  'caelum/vraptor',
#  'caelum/vraptor4',
#  'calrissian/accumulo-recipes',
#  'calrissian/mango',
#  'calvinaquino/LNReader-Android',
#  'camunda/camunda-bpm-platform',
#  'candlepin/candlepin',
#  'capedwarf/capedwarf-blue',
#  'Catrobat/Catroid',
#  'Catrobat/Paintroid',
#  'cats-oss/android-gpuimage',
#  'CAU-Kiel-Tech-Inf/socha',
#  'cbeust/jcommander',
#  'cbeust/testng-eclipse',
#  'cbeust/testng',
#  'CCI-MIT/XCoLab',
#  'ccw-ide/ccw',
#  'cdi-unit/cdi-unit',
#  'cdk/cdk',
#  'celements/celements-core',
#  'CellularPrivacy/Android-IMSI-Catcher-Detector',
#  'CeON/CoAnSys',
#  'cerberustesting/cerberus-source',
#  'CESNET/perun',
#  'cexbrayat/linkit',
#  'ceylon/ceylon-compiler',
#  'ceylon/ceylon.language',
#  'cgeo/cgeo',
#  'champo/TPE-PAW',
#  'ChangeOrientedProgrammingEnvironment/eclipseRecorder',
#  'chariotsolutions/phonegap-nfc',
#  'charite/jannovar',
#  'checkstyle/checkstyle',
#  'chennaione/sugar',
#  'chewiebug/GCViewer',
#  'ChiralBehaviors/Ultrastructure',
#  'chocoteam/choco-solver',
#  'chorhatarahuduketuri/gc',
#  'chrisbanes/PhotoView',
#  'cinchapi/concourse',
#  'CitizensDev/Citizens2',
#  'citlab/vs.msc.ws13',
#  'citrusframework/citrus',
#  'cloudbees/zendesk-java-client',
#  'cloudfoundry/cf-java-client',
#  'cloudfoundry/uaa',
#  'cloudinary/cloudinary_android',
#  'cloudinary/cloudinary_java',
#  'Cloudname/cloudname',
#  'clusterbench/clusterbench',
#  'code-troopers/android-betterpickers',
#  'codebutler/farebot',
#  'codelibs/fess',
#  'codenvy-legacy/ide',
#  'codenvy-legacy/platform-api-client-gwt',
#  'codenvy-legacy/platform-api',
#  'codepath/android-rest-client-template',
#  'coderplay/dragon',
#  'codinguser/gnucash-android',
#  'coffeine-009/Virtuoso',
#  'Cognifide/Slice',
#  'coldstar96/cse403',
#  'collectivemedia/celos',
#  'cometd/cometd',
#  'Commonjava/atlas',
#  'Commonjava/galley',
#  'Commonjava/indy',
#  'concordion/concordion',
#  'CONNECT-Solution/CONNECT',
#  'connectbot/connectbot',
#  'constantcontact/java-sdk',
#  'constretto/constretto-core',
#  'ControlSystemStudio/cs-studio',
#  'CorfuDB/CorfuDB',
#  'couchbase/couchbase-lite-android',
#  'couchbase/couchbase-lite-java-core',
#  'cpw/ironchest',
#  'craftercms/commons',
#  'craftercms/core',
#  'craftercms/engine',
#  'craftercms/profile',
#  'craftercms/search',
#  'craigwblake/redline',
#  'crashub/crash',
#  'crate/crate',
#  'crossbario/autobahn-java',
#  'crosswalk-project/crosswalk-cordova-android',
#  'crosswire/jsword',
#  'CS340Group/hit',
#  'CU-CommunityApps/cu-kfs',
#  'cucumber-attic/gherkin2',
#  'cucumber/cucumber-eclipse',
#  'cucumber/cucumber-jvm',
#  'CUTR-at-USF/usf-mobullity',
#  'cyclestreets/android',
#  'CyclopsMC/EvilCraft',
#  'd3scomp/JDEECo',
#  'dadoonet/fscrawler',
#  'dadoonet/spring-elasticsearch',
#  'daisy/pipeline-build-utils',
#  'daisy/pipeline-framework',
#  'daisy/pipeline-mod-tts',
#  'damianszczepanik/cucumber-reporting',
#  'damianszczepanik/maven-cucumber-reporting',
#  'dana-i2cat/opennaas',
#  'darkbtf/JazzChat',
#  'DataDog/jmxfetch',
#  'datasift/datasift-java',
#  'datastax/java-driver',
#  'davidB/scala-maven-plugin',
#  'DavidWhitlock/PortlandStateJava',
#  'daydreaming-experiment/app',
#  'dbfit/dbfit',
#  'dCache/dcache',
#  'dCache/oncrpc4j',
#  'dCache/xrootd4j',
#  'dcm4che/dcm4che',
#  'dcshock/forklift',
#  'Deadrik/TFCraft',
#  'deegree/deegree3',
#  'delving/sip-creator',
#  'DenizenScript/Denizen',
#  'DenizenScript/Depenizen',
#  'DependencyTrack/dependency-track',
#  'detro/ghostdriver',
#  'devhub-tud/devhub',
#  'devicehive/devicehive-java-server',
#  'Devskiller/jfairy',
#  'DFBnc/DFBnc',
#  'dhanji/sitebricks',
#  'DHBW-Karlsruhe/businesshorizon2_old',
#  'Diabol/delivery-pipeline-plugin',
#  'dianping/blackhole',
#  'dianping/cat',
#  'digipost/digipost-api-client-java',
#  'digital-preservation/droid',
#  'DigitalPebble/storm-crawler',
#  'dita-ot/dita-ot',
#  'DiUS/java-faker',
#  'dkomanov/fizteh-java-task',
#  'DMDirc/DMDirc',
#  'DMDirc/Parser',
#  'DMDirc/Plugins',
#  'DMDirc/Util',
#  'dmedov/flexymind_Ship',
#  'dmfs/opentasks',
#  'doanduyhai/Achilles',
#  'docusign/docusign-java-client',
#  'dolfdijkstra/gst-foundation',
#  'dotCMS/core',
#  'Double0negative/Survival-Games',
#  'DozerMapper/dozer',
#  'drallgood/jpasskit',
#  'dreamhead/moco',
#  'drewhannay/chess',
#  'DrKLO/Telegram',
#  'DroidPlanner/Tower',
#  'dropbox/dropbox-sdk-java',
#  'dropwizard-jobs/dropwizard-jobs',
#  'dropwizard/dropwizard-elasticsearch',
#  'dropwizard/dropwizard',
#  'dropwizard/metrics',
#  'drtshock/PlayerVaults',
#  'drtshock/Potato',
#  'drtshock/Willie',
#  'drugis/addis',
#  'drugis/mtc',
#  'druid-io/druid-api',
#  'DSH105/EchoPet',
#  'DSpace/DSpace',
#  'duckduckgo/android-search-and-stories',
#  'duke-compsci308-spring2013/vooga',
#  'duracloud/duracloud',
#  'dynjs/dynjs',
#  'e-ucm/ead',
#  'EaseTech/easytest-core',
#  'ebean-orm/ebean',
#  'ebi-gene-expression-group/atlas',
#  'eccentricdevotion/TARDIS',
#  'echo3/echo3',
#  'eclipse-color-theme/eclipse-color-theme',
#  'eclipse-ee4j/beanvalidation-api',
#  'eclipse-ee4j/beanvalidation-spec',
#  'eclipse-ee4j/beanvalidation-tck',
#  'eclipse-ee4j/cdi-tck',
#  'eclipse-ee4j/cdi',
#  'eclipse-vertx/vert.x',
#  'eclipse/deeplearning4j',
#  'eclipse/golo-lang',
#  'eclipse/jetty.project',
#  'eclipse/lyo.core',
#  'eclipse/mwe',
#  'eclipse/org.aspectj',
#  'eclipse/reddeer',
#  'eclipse/Xpect',
#  'EduMIPS64/edumips64',
#  'EFF/BilleterieR-O',
#  'EHRI/ehri-rest',
#  'eidottermihi/rpicheck',
#  'eirslett/frontend-maven-plugin',
#  'eishay/jvm-serializers',
#  'elastic/elasticsearch-hadoop',
#  'elastic/elasticsearch',
#  'elBukkit/MagicPlugin',
#  'Electrical-Age/ElectricalAge',
#  'elexis/elexis-3-base',
#  'elexis/elexis-3-core',
#  'ElgarL/Towny',
#  'EmilHernvall/tregmine',
#  'emilsjolander/StickyListHeaders',
#  'EngineHub/CommandBook',
#  'EngineHub/CommandHelper',
#  'EngineHub/CraftBook',
#  'EngineHub/WorldEdit',
#  'EngineHub/WorldGuard',
#  'enonic/xp',
#  'EnterpriseQualityCoding/FizzBuzzEnterpriseEdition',
#  'enviroCar/enviroCar-app',
#  'enviroCar/enviroCar-server',
#  'erickok/transdroid',
#  'errai/errai',
#  'ervandew/eclim',
#  'Escapecraft/EscapePlug',
#  'EsotericSoftware/yamlbeans',
#  'Esri/geometry-api-java',
#  'Esri/maps-app-android',
#  'Esri/solutions-geoevent-java',
#  'Esri/squad-leader-android',
#  'essentials/Essentials',
#  'estatio/estatio',
#  'eucalyptus/eucalyptus',
#  'eugenp/tutorials',
#  'europeana/api2',
#  'europeana/corelib',
#  'europeana/Europeana-Cloud',
#  'everit-org/jira-timetracker-plugin',
#  'Everteam-Software/tempo',
#  'evrythng/evrythng-java-sdk',
#  'exesoft/JSerialize',
#  'eXist-db/exist',
#  'eXist-db/messaging-replication',
#  'exo-archives/ks',
#  'exoplatform/calendar',
#  'exoplatform/ecms',
#  'exoplatform/exogtn',
#  'exoplatform/gatein-portal',
#  'exoplatform/integration',
#  'exoplatform/jcr',
#  'exoplatform/kernel',
#  'exoplatform/platform',
#  'exoplatform/social',
#  'exoplatform/wiki',
#  'ezScrum/ezScrum',
#  'fabioz/Pydev',
#  'facebookarchive/nifty',
#  'facebookarchive/swift',
#  'facebook/buck',
#  'facebook/facebook-android-sdk',
#  'facebook/nailgun',
#  'farin/JCloisterZone',
#  'FasterXML/jackson-core',
#  'FasterXML/jackson-databind',
#  'fcrepo4-archive/fcrepo-message-consumer',
#  'fcrepo4/fcrepo4',
#  'FeatureIDE/FeatureIDE',
#  'feedhenry/fh-android-sdk',
#  'feedzai/pdb',
#  'FEMR/femr',
#  'fenix-framework/fenix-framework',
#  'FenixEdu/bennu',
#  'FenixEdu/fenixedu-academic',
#  'FenixEdu/messaging',
#  'ff4j/ff4j',
#  'figo-connect/java-figo',
#  'filestack/filestack-android',
#  'find-sec-bugs/find-sec-bugs',
#  'Findwise/Hydra',
#  'FINRAOS/DataGenerator',
#  'FINRAOS/JTAF-ExtWebDriver',
#  'FlansMods/FlansMod',
#  'flapdoodle-oss/de.flapdoodle.embed.process',
#  'flaxsearch/luwak',
#  'Flipkart/phantom',
#  'floodlight/floodlight',
#  'flower-platform/flower-platform-3',
#  'FluentLenium/FluentLenium',
#  'fluxoid-org/CyclismoProject',
#  'flyingsaucerproject/flyingsaucer',
#  'flyway/flyway',
#  'forcedotcom/phoenix',
#  'forcedotcom/SalesforceMobileSDK-Android',
#  'forcedotcom/wsc',
#  'fordfrog/apgdiff',
#  'ForgeEssentials/ForgeEssentials',
#  'forge/core',
#  'forge/furnace',
#  'forge/roaster',
#  'foss-for-synopsys-dwc-arc-processors/arc_gnu_eclipse',
#  'fossasia/phimpme-android',
#  'foursquare/fongo',
#  'freedomotic/freedomotic',
#  'freenet/fred',
#  'freeplane/freeplane',
#  'functionaljava/functionaljava',
#  'Fundynamic/dune2themaker4j',
#  'fusesource/jansi',
#  'FXMisc/RichTextFX',
#  'galenframework/galen',
#  'gallandarakhneorg/afc',
#  'garbagemule/MobArena',
#  'gatein/gatein-portal',
#  'gdg-x/frisbee',
#  'genericworkflownodes/GenericKnimeNodes',
#  'geomajas/geomajas-project-client-gwt',
#  'geomajas/geomajas-project-client-gwt2',
#  'geomajas/geomajas-project-server',
#  'geonetwork/core-geonetwork',
#  'geopaparazzi/geopaparazzi',
#  'geoserver/geoserver',
#  'geosolutions-it/destination',
#  'geosolutions-it/geoserver-manager',
#  'geosolutions-it/geostore',
#  'geosolutions-it/imageio-ext',
#  'geosolutions-it/jai-ext',
#  'geotools/geotools',
#  'GeoWebCache/geowebcache',
#  'gephi/gephi',
#  'getsentry/sentry-java',
#  'ggp-org/ggp-base',
#  'git-commit-id/git-commit-id-maven-plugin',
#  'gitblit/gitblit',
#  'github-api/github-api',
#  'Glitchfiend/BiomesOPlenty',
#  'glob3mobile/g3m',
#  'GlowstoneMC/Glowstone-Legacy',
#  'glyptodon/guacamole-client',
#  'go-lang-plugin-org/go-lang-idea-plugin',
#  'gooddata/gooddata-http-client',
#  'googleads/aw-reporting',
#  'googleads/googleads-mobile-android-examples',
#  'GoogleCloudPlatform/appengine-tck',
#  'GoogleCloudPlatform/google-cloud-datastore',
#  'googlemaps/android-maps-utils',
#  'google/auto',
#  'google/compile-testing',
#  'google/jimfs',
#  'google/truth',
#  'Governance/dtgov',
#  'Governance/overlord-commons',
#  'Governance/rtgov',
#  'gradle/native-platform',
#  'graphhopper/graphhopper',
#  'graphhopper/jsprit',
#  'graphstream/gs-core',
#  'Graylog2/graylog2-server',
#  'greenrobot/greenDAO',
#  'greese/dasein-cloud-aws',
#  'greese/dasein-cloud-core',
#  'gresrun/jesque',
#  'griddynamics/jagger',
#  'groovy/groovy-core',
#  'groovy/groovy-eclipse',
#  'gtxcontentconnector/contentconnector',
#  'guardianproject/ChatSecureAndroid',
#  'guardianproject/NetCipher',
#  'gwt-maven-plugin/gwt-maven-plugin',
#  'gwtbootstrap3/gwtbootstrap3',
#  'gwtbootstrap/gwt-bootstrap',
#  'h2r/baking',
#  'ha-jdbc/ha-jdbc',
#  'Haehnchen/idea-php-annotation-plugin',
#  'Haehnchen/idea-php-symfony2-plugin',
#  'haiwen/seadroid',
#  'halestudio/hale',
#  'hal/core',
#  'hamcrest/JavaHamcrest',
#  'haraldk/TwelveMonkeys',
#  'HaraldWalker/user-agent-utils',
#  'hawtio/hawtio',
#  'hazelcast/hazelcast-code-samples',
#  'hazelcast/hazelcast-simulator',
#  'hazelcast/hazelcast',
#  'HdrHistogram/HdrHistogram',
#  'hector-client/hector',
#  'helloworld1/AnyMemo',
#  'helun/Ektorp',
#  'heroku/webapp-runner',
#  'hhru/nuts-and-bolts',
#  'hibernate/hibernate-ogm',
#  'hibernate/hibernate-orm',
#  'hibernate/hibernate-search',
#  'hibernate/hibernate-tools',
#  'hibernate/hibernate-validator',
#  'Hidendra/Plugin-Metrics',
#  'hierynomus/sshj',
#  'hmkcode/Java',
#  'HotswapProjects/HotswapAgent',
#  'hpcc-systems/EclipsePlugin',
#  'hpcc-systems/hpcc-jdbc',
#  'http-kit/http-kit',
#  'HubSpot/Baragon',
#  'HubSpot/dropwizard-guice',
#  'HubSpot/jackson-datatype-protobuf',
#  'HubSpot/Singularity',
#  'HumBuch/HumBuch',
#  'I-TECH/openmrs-module-kenyaemr',
#  'iball51860/java-server-client-football',
#  'ibissource/iaf',
#  'iBotPeaches/Apktool',
#  'ical4j/ical4j',
#  'iFixit/iFixitAndroid',
#  'ignatov/intellij-erlang',
#  'igniterealtime/Spark',
#  'igvteam/igv',
#  'iipc/openwayback',
#  'ikasanEIP/ikasan',
#  'imglib/imglib2',
#  'immutables/immutables',
#  'Impetus/Kundera',
#  'impossibl/pgjdbc-ng',
#  'ImpressiveCode/ic-depress',
#  'imrabti/myschool',
#  'infinispan/infinispan-server',
#  'infinispan/infinispan',
#  'infinispan/protostream',
#  'infiniteautomation/ma-core-public',
#  'infinitest/infinitest',
#  'InMobi/conduit',
#  'INRIA/spoon',
#  'IntegratedBreedingPlatform/Commons',
#  'IntegratedBreedingPlatform/Fieldbook',
#  'IntegratedBreedingPlatform/Middleware',
#  'Intel-bigdata/HiBench',
#  'intermine/intermine',
#  'internetarchive/heritrix3',
#  'ios-driver/ios-driver',
#  'iovation/launchkey-java',
#  'ipeirotis/Troia-Server',
#  'IPPETAD/adventure.datetime',
#  'ippontech/tatami',
#  'IQSS/dataverse',
#  'iron-io/iron_mq_java',
#  'ironjacamar/ironjacamar',
#  'IsmAvatar/LateralGM',
#  'ist-dsi/expenditures',
#  'italiangrid/storm',
#  'iuval/furry-octo-avenger',
#  'j-easy/easy-random',
#  'j-easy/easy-rules',
#  'j256/ormlite-core',
#  'jacoco/jacoco',
#  'JacORB/JacORB',
#  'jadler-mocking/jadler',
#  'JakeWharton/ActionBarSherlock',
#  'JakeWharton/butterknife',
#  'JakeWharton/DiskLruCache',
#  'JakeWharton/hugo',
#  'JakeWharton/u2020',
#  'JakeWharton/ViewPagerIndicator',
#  'jan-molak/jenkins-build-monitor-plugin',
#  'janrain/janrain-backplane-2',
#  'Jasig/CalendarPortlet',
#  'Jasig/email-preview',
#  'Jasig/NewsReaderPortlet',
#  'Jasig/NotificationPortlet',
#  'Jasig/SimpleContentPortlet',
#  'Jasig/uPortal',
#  'Jasig/WebproxyPortlet',
#  'Jaspersoft/js-android-sdk',
#  'java-native-access/jna',
#  'javaee-samples/javaee7-samples',
#  'javafunk/funk',
#  'javafx-maven-plugin/javafx-maven-plugin',
#  'javalite/javalite',
#  'JavaMoney/jsr354-ri',
#  'javaparser/javaparser',
#  'javaswift/joss',
#  'jbake-org/jbake',
#  'jbdevstudio/jbdevstudio-product',
#  'jberkel/sms-backup-plus',
#  'jboss-developer/jboss-eap-quickstarts',
#  'jboss-developer/jboss-jdg-quickstarts',
#  'jboss-javassist/javassist',
#  'jboss-logging/jboss-logging-tools',
#  'jboss-logging/jboss-logmanager',
#  'jboss-modules/jboss-modules',
#  'jboss-msc/jboss-msc',
#  'jboss-remoting/jboss-marshalling',
#  'jboss-remoting/jboss-remoting',
#  'jboss-set/pull-request-processor',
#  'jboss-set/pull-shared',
#  'jboss-switchyard/core',
#  'jboss-switchyard/tools',
#  'jbossas/jboss-as-maven-plugin',
#  'jbossas/jboss-threads',
#  'jbosstm/narayana',
#  'jbosstm/performance',
#  'jbosstm/quickstart',
#  'jbosstools/jbosstools-arquillian',
#  'jbosstools/jbosstools-base',
#  'jbosstools/jbosstools-central',
#  'jbosstools/jbosstools-forge',
#  'jbosstools/jbosstools-freemarker',
#  'jbosstools/jbosstools-hibernate',
#  'jbosstools/jbosstools-integration-stack-tests',
#  'jbosstools/jbosstools-integration-tests',
#  'jbosstools/jbosstools-javaee',
#  'jbosstools/jbosstools-jst',
#  'jbosstools/jbosstools-livereload',
#  'jbosstools/jbosstools-maven-plugins',
#  'jbosstools/jbosstools-openshift',
#  'jbosstools/jbosstools-server',
#  'jbosstools/jbosstools-vpe',
#  'jbosstools/jbosstools-webservices',
#  'jboss/metadata',
#  'jboss/mojarra',
#  'jcabi/jcabi-aspects',
#  'jcabi/jcabi-github',
#  'jcabi/jcabi-xml',
#  'jchambers/pushy',
#  'jclouds/jclouds-examples',
#  'jclouds/jclouds-karaf',
#  'jclouds/jclouds-labs-aws',
#  'jclouds/jclouds-labs-openstack',
#  'jclouds/jclouds-labs',
#  'jclouds/jclouds',
#  'jclouds/legacy-jclouds-karaf',
#  'jclouds/legacy-jclouds-labs',
#  'jclouds/legacy-jclouds',
#  'jcodec/jcodec',
#  'jcryptool/crypto',
#  'jdbi/jdbi',
#  'jdeferred/jdeferred',
#  'jDramaix/gss.gwt',
#  'jembi/bsis',
#  'jenkins-infra/account-app',
#  'jenkins-infra/ircbot',
#  'jenkins-infra/update-center2',
#  'jenkinsci/accurev-plugin',
#  'jenkinsci/active-directory-plugin',
#  'jenkinsci/analysis-core-plugin',
#  'jenkinsci/android-emulator-plugin',
#  'jenkinsci/ansicolor-plugin',
#  'jenkinsci/bitbucket-plugin',
#  'jenkinsci/branch-api-plugin',
#  'jenkinsci/build-failure-analyzer-plugin',
#  'jenkinsci/build-timeout-plugin',
#  'jenkinsci/buildtriggerbadge-plugin',
#  'jenkinsci/claim-plugin',
#  'jenkinsci/cloudbees-folder-plugin',
#  'jenkinsci/cobertura-plugin',
#  'jenkinsci/config-file-provider-plugin',
#  'jenkinsci/copyartifact-plugin',
#  'jenkinsci/credentials-binding-plugin',
#  'jenkinsci/credentials-plugin',
#  'jenkinsci/cucumber-reports-plugin',
#  'jenkinsci/custom-tools-plugin',
#  'jenkinsci/cvs-plugin',
#  'jenkinsci/dashboard-view-plugin',
#  'jenkinsci/ec2-plugin',
#  'jenkinsci/email-ext-plugin',
#  'jenkinsci/envinject-plugin',
#  'jenkinsci/gerrit-trigger-plugin',
#  'jenkinsci/ghprb-plugin',
#  'jenkinsci/git-client-plugin',
#  'jenkinsci/github-oauth-plugin',
#  'jenkinsci/github-plugin',
#  'jenkinsci/gradle-plugin',
#  'jenkinsci/htmlpublisher-plugin',
#  'jenkinsci/jacoco-plugin',
#  'jenkinsci/java-client-api',
#  'jenkinsci/jclouds-plugin',
#  'jenkinsci/jenkins',
#  'jenkinsci/jira-plugin',
#  'jenkinsci/jobConfigHistory-plugin',
#  'jenkinsci/mailer-plugin',
#  'jenkinsci/matrix-auth-plugin',
#  'jenkinsci/matrix-project-plugin',
#  'jenkinsci/maven-hpi-plugin',
#  'jenkinsci/maven-plugin',
#  'jenkinsci/mercurial-plugin',
#  'jenkinsci/mesos-plugin',
#  'jenkinsci/parallel-test-executor-plugin',
#  'jenkinsci/parameterized-trigger-plugin',
#  'jenkinsci/perforce-plugin',
#  'jenkinsci/performance-plugin',
#  'jenkinsci/platformlabeler-plugin',
#  'jenkinsci/plot-plugin',
#  'jenkinsci/plugin-compat-tester',
#  'jenkinsci/promoted-builds-plugin',
#  'jenkinsci/rebuild-plugin',
#  'jenkinsci/remoting',
#  'jenkinsci/role-strategy-plugin',
#  'jenkinsci/sauce-ondemand-plugin',
#  'jenkinsci/scm-api-plugin',
#  'jenkinsci/selenium-plugin',
#  'jenkinsci/slack-plugin',
#  'jenkinsci/sloccount-plugin',
#  'jenkinsci/ssh-credentials-plugin',
#  'jenkinsci/ssh-slaves-plugin',
#  'jenkinsci/stashnotifier-plugin',
#  'jenkinsci/subversion-plugin',
#  'jenkinsci/support-core-plugin',
#  'jenkinsci/swarm-plugin',
#  'jenkinsci/tfs-plugin',
#  'jenkinsci/throttle-concurrent-builds-plugin',
#  'jenkinsci/timestamper-plugin',
#  'jenkinsci/violations-plugin',
#  'jenkinsci/vsphere-cloud-plugin',
#  'jenkinsci/warnings-plugin',
#  'jenkinsci/windows-azure-storage-plugin',
#  'jenkinsci/winstone',
#  'jenkinsci/xldeploy-plugin',
#  'jenkinsci/xunit-plugin',
#  'jeo/jeo',
#  'jeremylong/DependencyCheck',
#  'jersey/jersey',
#  'JesusFreke/smali',
#  'JetBrains/Grammar-Kit',
#  'JetBrains/jediterm',
#  'JetBrains/jetpad-projectional-open-source',
#  'JetBrains/mapper',
#  'JetBrains/pty4j',
#  'jfeinstein10/SlidingMenu',
#  'jfrog/artifactory-client-java',
#  'jfrog/bamboo-artifactory-plugin',
#  'jfrog/build-info',
#  'JFXtras/jfxtras-labs',
#  'jglobus/JGlobus',
#  'jhy/jsoup',
#  'jitsi/jitsi-videobridge',
#  'jitsi/jitsi',
#  'jitsi/libjitsi',
#  'jjoe64/GraphView',
#  'jknack/handlebars.java',
#  'jkuhnert/ognl',
#  'jline/jline2',
#  'jmeter-maven-plugin/jmeter-maven-plugin',
#  'jmock-developers/jmock-library',
#  'jmxtrans/embedded-jmxtrans',
#  'jmxtrans/jmxtrans-agent',
#  'jmxtrans/jmxtrans',
#  'JnRouvignac/AutoRefactor',
#  'jnr/jnr-ffi',
#  'jnr/jnr-posix',
#  'JodaOrg/joda-time',
#  'joel-costigliola/assertj-core',
#  'joelittlejohn/jsonschema2pojo',
#  'johncarl81/parceler',
#  'johncarl81/transfuse',
#  'jonasoreland/runnerup',
#  'jopt-simple/jopt-simple',
#  'joscha/play-authenticate',
#  'joshdholtz/Sentry-Android',
#  'joshjdevl/libsodium-jni',
#  'joyent/java-manta',
#  'jphp-group/jphp',
#  'jpos/jPOS-EE',
#  'jpos/jPOS',
#  'jReddit/jReddit',
#  'jruby/jruby-openssl',
#  'jscep/jscep',
#  'json-path/JsonPath',
#  'jsonld-java/jsonld-java',
#  'JSQLParser/JSqlParser',
#  'jtalks-org/functional-tests',
#  'jtalks-org/jcommune',
#  'julianhyde/optiq',
#  'julianhyde/sqlline',
#  'junit-team/junit4',
#  'junkdog/artemis-odb',
#  'juzu/juzu',
#  'k9mail/k-9',
#  'kairosdb/kairosdb',
#  'kaltura/media-server',
#  'kaltura/player-sdk-native-android',
#  'katzer/cordova-plugin-local-notifications',
#  'keenlabs/KeenClient-Java',
#  'keeps/roda',
#  'kenglxn/QRGen',
#  'KengoTODA/findbugs-slf4j',
#  'kermitt2/grobid',
#  'keycloak/keycloak',
#  'kframework/k-legacy',
#  'kiegroup/drools-wb',
#  'kiegroup/drools',
#  'kiegroup/droolsjbpm-integration',
#  'kiegroup/droolsjbpm-knowledge',
#  'kiegroup/droolsjbpm-tools',
#  'kiegroup/jbpm-wb',
#  'kiegroup/jbpm',
#  'kiegroup/kie-wb-common',
#  'kiegroup/kie-wb-distributions',
#  'kiegroup/optaplanner',
#  'kijiproject/kiji-mapreduce',
#  'kijiproject/kiji-schema',
#  'killbilling/recurly-java-library',
#  'killbill/killbill-analytics-plugin',
#  'killbill/killbill-api',
#  'killbill/killbill-client-java',
#  'killbill/killbill-commons',
#  'killbill/killbill',
#  'kite-sdk/kite',
#  'kitodo/kitodo-production',
#  'KKBOX/android_kktoolkit',
#  'klarna/HiveRunner',
#  'knime-ip/knip',
#  'knowm/XChange',
#  'knowm/XChart',
#  'kobakei/Android-RateThisApp',
#  'kohsuke/args4j',
#  'KomodoOpenLab/TeclaAccess',
#  'komoot/photon',
#  'kongchen/swagger-maven-plugin',
#  'Kong/unirest-java',
#  'konklone/congress-android',
#  'konsoletyper/teavm',
#  'koush/AndroidAsync',
#  'koush/ion',
#  'labexp/osmtracker-android',
#  'languagetool-org/languagetool',
#  'leolin310148/ShortcutBadger',
#  'liato/android-bankdroid',
#  'libgdx/ashley',
#  'libgdx/libgdx',
#  'LibraryOfCongress/bagit-java',
#  'librato/metrics-librato',
#  'liferay/liferay-faces',
#  'lightbend/config',
#  'lightblue-platform/lightblue-core',
#  'linkedin/ambry',
#  'linkedin/camus',
#  'linkedin/datafu',
#  'linkedin/parseq',
#  'linkedin/rest.li',
#  'linkedin/sensei',
#  'lintool/Cloud9',
#  'liquibase/liquibase',
#  'lithiumtech/rdbi',
#  'LiveRamp/cascading_ext',
#  'LiveRamp/hank',
#  'LiveRamp/jack',
#  'llbit/chunky',
#  'LMAX-Exchange/disruptor',
#  'lobid/lodmill',
#  'lob/lob-java',
#  'locationtech/spatial4j',
#  'locationtech/udig-platform',
#  ...]

# %% [markdown]
# ### Get two_months ago's timestamp

# %%
two_months_ago = datetime.now() - timedelta(days=60)

# %% [markdown]
# ### Set up PyGithub variables

# %%
# Create personal token under GitHub settings
token = "MY_TOKEN"

# %%
g = Github(token)

print(g.rate_limiting)
print(g.rate_limiting_resettime)
# Out:
# (5000, 5000)
# 1684496676

# %% [markdown]
# ### Run script

# %%
entries = gh_projects

# %%
for entry in entries:
    repo_name = entry

    try:
        repo = g.get_repo(repo_name)
        pulls = repo.get_pulls(state='closed', sort='created', direction='desc')
        recent_pull_requests = [pr for pr in pulls if pr.created_at >= two_months_ago]

        if recent_pull_requests:
            print(f"Extracting {repo_name} data ({len(recent_pull_requests)} pull requests) ...")
            review_ids = []
            review_datas = []
            for pull in recent_pull_requests:
                reviews = pull.get_reviews()
                for review in reviews:
                    #print(review.raw_data)
                    review_data = {
                        "project": repo_name,
                        "pull_number": pull.number,
                        "pull_id": pull.id,
                        "review_id": review.raw_data["id"],
                        "user": review.raw_data["user"]["login"],
                        "user_id": review.raw_data["user"]["id"],
                        "message": review.raw_data["body"],
                        "state": review.raw_data["state"],
                        "submitted_at": review.raw_data["submitted_at"],
                        "pull_request_id": review.raw_data["pull_request_url"].split("/")[-1],
                        "pull_request_url": review.raw_data["pull_request_url"],
                        "commit_id" : review.raw_data["commit_id"] if "commit_id" in review.raw_data else None,  
                        "comments" : []
                    }
                    review_datas.append(review_data)

            for pull in recent_pull_requests:
                review_comments = pull.get_review_comments()

                for review_comment in review_comments:
                    pr_review_id = extract_data(review_comment.raw_data, "pull_request_review_id")

                    commit_before_id = extract_data(pull.raw_data["base"], "sha")
                    commit_while_id = extract_data(review_comment.raw_data, "original_commit_id")
                    commit_after_id = extract_data(review_comment.raw_data, "commit_id")
                    
                    commit_before = get_commit(repo,commit_before_id)
                    commit_while = get_commit(repo,commit_while_id)
                    commit_after = get_commit(repo,commit_after_id)
                #print(commit_before.raw_data["files"][0])
                    try:
                        comment_data = {
                            "comment_id" : extract_data(review_comment.raw_data, "id"),
                            "commit_id" : extract_data(review_comment.raw_data, "commit_id"),
                            "original_commit_id" : extract_data(review_comment.raw_data, "original_commit_id"),
                            "html_url": extract_data(review_comment.raw_data, "html_url"),
                            "user_id" : extract_data(review_comment.raw_data["user"], "id"),
                            "comment" :  extract_data(review_comment.raw_data, "body"),
                            "created_at" : extract_data(review_comment.raw_data, "created_at"),
                            "updated_at" : extract_data(review_comment.raw_data, "updated_at"),
                            "start_line" : extract_data(review_comment.raw_data, "start_line"),
                            "original_start_line" : extract_data(review_comment.raw_data, "original_start_line"),
                            "original_line" : extract_data(review_comment.raw_data, "original_line"),
                            "start_side" : extract_data(review_comment.raw_data, "start_side"),
                            "side" : extract_data(review_comment.raw_data, "side"),
                            "line" : extract_data(review_comment.raw_data, "line"),
                            "filename" : extract_data(review_comment.raw_data, "path"),
                            "commit_before" : commit_before_id,
                            "commit_while" : commit_while_id,
                            "commit_after" : commit_after_id,
                            "url_source_before" : extract_data(commit_before.raw_data["files"][0], "raw_url") if commit_before is not None else None,
                            "url_source_while" : extract_data(commit_while.raw_data["files"][0], "raw_url") if commit_while is not None else None,
                            "url_source_after" : extract_data(commit_after.raw_data["files"][0], "raw_url") if commit_after is not None else None,
                            "file_content_before" : get_file_content(find_file(commit_before.raw_data["files"], review_comment.raw_data["path"])) if commit_before is not None else None,
                            "file_content_while" : get_file_content(find_file(commit_while.raw_data["files"], review_comment.raw_data["path"])) if commit_while is not None else None,
                            "file_content_after" : get_file_content(find_file(commit_after.raw_data["files"], review_comment.raw_data["path"])) if commit_after is not None else None,

                        }

                    except:
                        pass

                    if pr_review_id is not None:
                        # in the review_datas find the review_id and add the comment to the review
                        for current_review_data in review_datas:
                            if current_review_data["review_id"] == pr_review_id:
                                current_review_data["comments"].append(comment_data)
                                break

            
            filtered_review_datas = [review for review in review_datas if not review['comments'] == []]



            new_data = pd.DataFrame(columns=['project',
                                            'url',
                                            'discussion',
                                            'pull_number',
                                            'pull_id',
                                            'filename',
                                            'start_line',
                                            'original_start_line',
                                            'start_side',
                                            'side',
                                            'line',
                                            'original_line',
                                            'message',
                                            'owner_id',
                                            'user_id',
                                            'created_at',
                                            'updated_at',
                                            'commit_before',
                                            'commit_while',
                                            'commit_after',
                                            'url_source_before',
                                            'url_source_while',
                                            'url_source_after',
                                            'file_content_before',
                                            'file_content_while',
                                            'file_content_after'])
            
            for filtered_review_data in filtered_review_datas:
                for comment in filtered_review_data['comments']:
                    data = {'project': filtered_review_data['project'],
                            'url': 'https://github.com/'+ filtered_review_data['project'],
                            'discussion': comment['html_url'],
                            'pull_number': filtered_review_data['pull_number'],
                            'pull_id': filtered_review_data['pull_id'],
                            'filename': comment['filename'],
                            'start_line': comment['start_line'],
                            'original_start_line': comment['original_start_line'],
                            'start_side': comment['start_side'],
                            'side': comment['side'],
                            'line': comment['line'],
                            'original_line': comment['original_line'],
                            'message': comment['comment'],
                            'owner_id': filtered_review_data['user_id'],
                            'user_id': comment['user_id'],
                            'created_at': comment['created_at'],
                            'updated_at': comment['updated_at'],
                            'commit_before': comment['commit_before'],
                            'commit_while': comment['commit_while'],
                            'commit_after': comment['commit_after'],
                            'url_source_before': comment['url_source_before'],
                            'url_source_while': comment['url_source_while'],
                            'url_source_after': comment['url_source_after'],
                            'file_content_before': comment['file_content_before'],
                            'file_content_while': comment['file_content_while'],
                            'file_content_after': comment['file_content_after']
                            }

                        


                    df_dictionary = pd.DataFrame([data])
                    new_data = pd.concat([new_data, df_dictionary], ignore_index=True)

            new_data = new_data[new_data['file_content_before'] != new_data['file_content_after']].reset_index(drop=True)
            new_data = new_data[new_data['file_content_while'].notna()].reset_index(drop=True)
            new_data = new_data[new_data['file_content_after'].notna()].reset_index(drop=True)
            
            if not new_data.empty:
                print(f"Saving {repo_name} data...")
                repo_name = repo_name.replace('/', '_') + ".csv"
                new_data.to_csv(new_gh_data_dir + repo_name, index=False)

    except GithubException as e :
        if e.status == 403:
            handle_rate_limit_exception(e)
# Out:
# Extracting 52North/sensorweb-server-helgoland data (2 pull requests) ...
# Extracting ACRA/acra data (18 pull requests) ...
# Extracting Activiti/Activiti data (7 pull requests) ...
# Saving Activiti/Activiti data...
# Extracting AddstarMC/Minigames data (1 pull requests) ...
# Extracting AddstarMC/Prism-Bukkit data (2 pull requests) ...
# Extracting adjust/android_sdk data (1 pull requests) ...
# Extracting Adobe-Consulting-Services/acs-aem-commons data (13 pull requests) ...
# Saving Adobe-Consulting-Services/acs-aem-commons data...
# Extracting airlift/airlift data (12 pull requests) ...
# Saving airlift/airlift data...
# Extracting airlift/slice data (2 pull requests) ...
# Extracting Alfresco/gytheio data (44 pull requests) ...
# Extracting alibaba/canal data (1 pull requests) ...
# Extracting alibaba/druid data (15 pull requests) ...
# Extracting alibaba/fastjson data (1 pull requests) ...
# Extracting alkacon/opencms-core data (1 pull requests) ...
# Extracting Alluxio/alluxio data (213 pull requests) ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 15
#      13 for pull in recent_pull_requests:
#      14     reviews = pull.get_reviews()
# ---> 15     for review in reviews:
#      16         #print(review.raw_data)
#      17         review_data = {
#      18             "project": repo_name,
#      19             "pull_number": pull.number,
#    (...)
#      30             "comments" : []
#      31         }
#      32         review_datas.append(review_data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\github\PaginatedList.py:56, in PaginatedListBase.__iter__(self)
#      54 yield from self.__elements
#      55 while self._couldGrow():
# ---> 56     newElements = self._grow()
#      57     yield from newElements
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\github\PaginatedList.py:67, in PaginatedListBase._grow(self)
#      66 def _grow(self):
# ---> 67     newElements = self._fetchNextPage()
#      68     self.__elements += newElements
#      69     return newElements
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\github\PaginatedList.py:201, in PaginatedList._fetchNextPage(self)
#     200 def _fetchNextPage(self):
# --> 201     headers, data = self.__requester.requestJsonAndCheck(
#     202         "GET", self.__nextUrl, parameters=self.__nextParams, headers=self.__headers
#     203     )
#     204     data = data if data else []
#     206     self.__nextUrl = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\github\Requester.py:399, in Requester.requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     397 def requestJsonAndCheck(self, verb, url, parameters=None, headers=None, input=None):
#     398     return self.__check(
# --> 399         *self.requestJson(
#     400             verb, url, parameters, headers, input, self.__customConnection(url)
#     401         )
#     402     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\github\Requester.py:499, in Requester.requestJson(self, verb, url, parameters, headers, input, cnx)
#     496 def encode(input):
#     497     return "application/json", json.dumps(input)
# --> 499 return self.__requestEncode(cnx, verb, url, parameters, headers, input, encode)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\github\Requester.py:573, in Requester.__requestEncode(self, cnx, verb, url, parameters, requestHeaders, input, encode)
#     569     requestHeaders["Content-Type"], encoded_input = encode(input)
#     571 self.NEW_DEBUG_FRAME(requestHeaders)
# --> 573 status, responseHeaders, output = self.__requestRaw(
#     574     cnx, verb, url, requestHeaders, encoded_input
#     575 )
#     577 if (
#     578     Consts.headerRateRemaining in responseHeaders
#     579     and Consts.headerRateLimit in responseHeaders
#     580 ):
#     581     self.rate_limiting = (
#     582         int(responseHeaders[Consts.headerRateRemaining]),
#     583         int(responseHeaders[Consts.headerRateLimit]),
#     584     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\github\Requester.py:600, in Requester.__requestRaw(self, cnx, verb, url, requestHeaders, input)
#     598     cnx = self.__createConnection()
#     599 cnx.request(verb, url, input, requestHeaders)
# --> 600 response = cnx.getresponse()
#     602 status = response.status
#     603 responseHeaders = {k.lower(): v for k, v in response.getheaders()}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\github\Requester.py:131, in HTTPSRequestsConnectionClass.getresponse(self)
#     129 verb = getattr(self.session, self.verb.lower())
#     130 url = f"{self.protocol}://{self.host}:{self.port}{self.url}"
# --> 131 r = verb(
#     132     url,
#     133     headers=self.headers,
#     134     data=self.input,
#     135     timeout=self.timeout,
#     136     verify=self.verify,
#     137     allow_redirects=False,
#     138 )
#     139 return RequestsResponse(r)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:542, in Session.get(self, url, **kwargs)
#     534 r"""Sends a GET request. Returns :class:`Response` object.
#     535
#     536 :param url: URL for the new :class:`Request` object.
#     537 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     538 :rtype: requests.Response
#     539 """
#     541 kwargs.setdefault('allow_redirects', True)
# --> 542 return self.request('GET', url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
